# %% [markdown]
# <a href="https://colab.research.google.com/github/beam2547/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ปานฤทัย พันธ์สวัสดิ์

# %%
print('663020263-8')
# Out:
# 663020263-8
